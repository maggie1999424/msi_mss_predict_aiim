# %%
import pandas as pd

# %%
df_val = pd.read_csv('c:\\Users\\maggie1999424\\Downloads\\Val_list_0_Raw')
df_train = pd.read_csv('c:\\Users\\maggie1999424\\Downloads\\Train_list_0_Raw')

# %%
df_t = pd.concat([df_val,df_train])

# %%
df_t.sample(len(df_t),replace=False)
# Out:
#          index                                               Path  \
# 27995    93165  kaggle-MSI/MSIMUT_JPEG/blk-LIEGDDCWFSFI-TCGA-C...
# 27119   177126  kaggle-MSI/MSIMUT_JPEG/blk-LFMRWGPSYGSP-TCGA-G...
# 102796  189059  kaggle-MSI/MSIMUT_JPEG/blk-YTQSWDIEHVSK-TCGA-Q...
# 73252    75941  kaggle-MSI/MSS_JPEG/blk-VMWYHNCQLMMS-TCGA-CA-6...
# 78343    91124  kaggle-MSI/MSIMUT_JPEG/blk-EIATFIQYSDGY-TCGA-C...
# ...        ...                                                ...
# 61823    25470  kaggle-MSI/MSIMUT_JPEG/blk-AFWKSNFQGRSH-TCGA-A...
# 20775   141500  kaggle-MSI/MSS_JPEG/blk-QVELEQLTWKDT-TCGA-DM-A...
# 116518   49448  kaggle-MSI/MSS_JPEG/blk-WEYFFPVAMKDW-TCGA-AG-A...
# 55936    84641  kaggle-MSI/MSIMUT_JPEG/blk-IGRRMAVQIANY-TCGA-C...
# 36435    24732  kaggle-MSI/MSIMUT_JPEG/blk-SQCVESQEQWVE-TCGA-A...
#
#                                            imagename  Y            ID orilab
# 27995   blk-LIEGDDCWFSFI-TCGA-CM-4743-01Z-00-DX1.jpg  1  TCGA-CM-4743  MSI-H
# ...

# %%
df_val_new = df_t.iloc[:int(len(df_t)/5)]
df_train_new = df_t.iloc[int(len(df_t)/5):]

# %%
df_val_new.to_csv('c:\\Users\\maggie1999424\\Downloads\\Val_list_0_Mix',index=False)
df_train_new.to_csv('c:\\Users\\maggie1999424\\Downloads\\Train_list_0_Mix',index=False)
